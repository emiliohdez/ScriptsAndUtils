# %%
import zeep #Debes tener instalada esta biblioteca, utiliza: pip install zeep

wsdl = 'http://ftp.conagua.gob.mx/google/google.asmx?WSDL'
client = zeep.Client(wsdl=wsdl)
print(client.service.DireccionVientoHoraria('2020/06/12 09:00:00'))
# Out:
# [{"Estacion":"CHINCHORROmar","Dirviento":"269","Fecha":"12/06/2020 07:00:00 a. m."},{"Estacion":"CHINCHORROmar","Dirviento":"5","Fecha":"12/06/2020 07:15:00 a. m."},{"Estacion":"CHINCHORROmar","Dirviento":"69","Fecha":"12/06/2020 07:30:00 a. m."},{"Estacion":"CHINCHORROmar","Dirviento":"71","Fecha":"12/06/2020 07:45:00 a. m."},{"Estacion":"CHINCHORROmar","Dirviento":"34","Fecha":"12/06/2020 08:00:00 a. m."},{"Estacion":"CHINCHORROmar","Dirviento":"62","Fecha":"12/06/2020 08:15:00 a. m."},{"Estacion":"CHINCHORROmar","Dirviento":"38","Fecha":"12/06/2020 08:30:00 a. m."},{"Estacion":"CHINCHORROmar","Dirviento":"28","Fecha":"12/06/2020 08:45:00 a. m."},{"Estacion":"CHNCH","Dirviento":"39","Fecha":"12/06/2020 07:00:00 a. m."},{"Estacion":"CHNCH","Dirviento":"24","Fecha":"12/06/2020 07:10:00 a. m."},{"Estacion":"CHNCH","Dirviento":"32","Fecha":"12/06/2020 07:20:00 a. m."},{"Estacion":"CHNCH","Dirviento":"31","Fecha":"12/06/2020 07:30:00 a. m."},{"Estacion":"CHNCH","Dirviento":"22","Fecha":
# ...
